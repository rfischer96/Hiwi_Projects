# %%
import pandas as pd
import pandas as pd
from collections import Counter
import re

# %%
df = pd.read_excel("/Users/robinfischer/Desktop/HSall_rollcalls.xlsx")
df
# Out:
#         congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 0              1   House           1  1789-05-16      NaN               NaN
# 1              1   House           2  1789-05-22      NaN               NaN
# 2              1   House           3  1789-06-22      NaN               NaN
# 3              1   House           4  1789-06-22      NaN               NaN
# 4              1   House           5  1789-06-24      NaN               NaN
# ...          ...     ...         ...         ...      ...               ...
# 110278       118  Senate          65  2023-03-22      1.0              65.0
# 110279       118  Senate          66  2023-03-22      1.0              66.0
# 110280       118  Senate          67  2023-03-23      1.0              67.0
# 110281       118  Senate          68  2023-03-23      1.0              68.0
# 110282       118  Senate          69  2023-03-23      1.0              69.0
#
#         yea_count  nay_count  nominate_mid_1  nominate_mid_2  \
# 0              41          8           484.0          -872.0
# 1              36          1           256.0           967.0
# 2              30         18          -394.0          -454.0
# 3              31         19          -194.0          -981.0
# 4              29         22          -197.0          -266.0
# ...           ...        ...             ...             ...
# 110278          9         86          -782.0           588.0
# 110279         36         60          -411.0           615.0
# 110280         19         76           896.0           445.0
# 110281         32         63          -574.0           741.0
# 110282         41         52          -405.0           914.0
#
#         nominate_spread_1  nominate_spread_2  nominate_log_likelihood  \
# 0                  229.00            -378.00                -13144.00
# 1                   -0.09            1791.00                    -1.90
# 2                 -176.00             922.00                -22048.00
# 3                   81.00            -327.00                -30355.00
# 4                 -168.00             984.00                -22221.00
# ...                   ...                ...                      ...
# 110278             319.00               0.42                -18693.00
# 110279            -277.00              -1.62                -26239.00
# 110280              -0.28             772.00                   -31.67
# 110281            -232.00           -1509.00                -32955.00
# 110282            -259.00            -679.00                -21274.00
#
#        bill_number         vote_result  \
# 0              HR2                 NaN
# 1              NaN                 NaN
# 2              HR8                 NaN
# 3              HR8                 NaN
# 4              HR8                 NaN
# ...            ...                 ...
# 110278        S316  Amendment Rejected
# 110279        S316  Amendment Rejected
# 110280        S316  Amendment Rejected
# 110281        S316  Amendment Rejected
# 110282        S316  Amendment Rejected
#
#                                                 vote_desc     vote_question  \
# 0                                                     NaN               NaN
# 1                                                     NaN               NaN
# 2                                                     NaN               NaN
# 3                                                     NaN               NaN
# 4                                                     NaN               NaN
# ...                                                   ...               ...
# 110278  To repeal the 2001 Authorization for Use of Mi...  On the Amendment
# 110279  To provide for more targeted authority under t...  On the Amendment
# 110280  To provide for the termination of authorizatio...  On the Amendment
# 110281                        To require a certification.  On the Amendment
# 110282  To provide for a delayed, conditional repeal o...  On the Amendment
#
#                                                  dtl_desc
# 0       TO AMEND H.R. 2, (1 STAT. 24, APP. 7-4-1789), ...
# 1       TO PASS THE RESOLUTION THAT IT APPEARS TO THIS...
# 2       TO AMEND H.R. 8, (1 STAT. 28, APP. 7-27-1789),...
# 3       TO AMEND H.R. 8, SO AS TO ELIMINATE THE PRESID...
# 4                                         TO PASS H.R. 8.
# ...                                                   ...
# 110278                                                NaN
# 110279                                                NaN
# 110280                                                NaN
# 110281                                                NaN
# 110282                                                NaN
#
# [110283 rows x 18 columns]

# %%
# Entferne Zeilen mit fehlenden Werten in dtl_desc
df = df.dropna(subset=['dtl_desc'])
df
# Out:
#        congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 0             1   House           1  1789-05-16      NaN               NaN
# 1             1   House           2  1789-05-22      NaN               NaN
# 2             1   House           3  1789-06-22      NaN               NaN
# 3             1   House           4  1789-06-22      NaN               NaN
# 4             1   House           5  1789-06-24      NaN               NaN
# ...         ...     ...         ...         ...      ...               ...
# 87946       106   House        1205  2000-12-04      2.0             599.0
# 87947       106   House        1206  2000-12-05      2.0             600.0
# 87948       106   House        1207  2000-12-07      2.0             601.0
# 87949       106   House        1208  2000-12-08      2.0             602.0
# 87950       106   House        1209  2000-12-15      2.0             603.0
#
#        yea_count  nay_count  nominate_mid_1  nominate_mid_2  \
# 0             41          8          484.00          -872.0
# 1             36          1          256.00           967.0
# 2             30         18         -394.00          -454.0
# 3             31         19         -194.00          -981.0
# 4             29         22         -197.00          -266.0
# ...          ...        ...             ...             ...
# 87946        348          6            0.00             0.0
# 87947        378          6            0.00             0.0
# 87948        359         11          955.00          -295.0
# 87949        284         37           -0.54           -99.0
# 87950        292         60            0.57           -95.0
#
#        nominate_spread_1  nominate_spread_2  nominate_log_likelihood  \
# 0                 229.00             -378.0                 -13144.0
# 1                  -0.09             1791.0                     -1.9
# 2                -176.00              922.0                 -22048.0
# 3                  81.00             -327.0                 -30355.0
# 4                -168.00              984.0                 -22221.0
# ...                  ...                ...                      ...
# 87946               0.00                0.0                      0.0
# 87947               0.00                0.0                      0.0
# 87948             292.00              299.0                 -39988.0
# 87949            -243.00              133.0                 -70019.0
# 87950             157.00              -14.0                -113952.0
#
#       bill_number vote_result  \
# 0             HR2         NaN
# 1             NaN         NaN
# 2             HR8         NaN
# 3             HR8         NaN
# 4             HR8         NaN
# ...           ...         ...
# 87946       S1761      Passed
# 87947    HJRES126      Passed
# 87948    HJRES127      Passed
# 87949    HJRES128      Passed
# 87950      HR4577      Passed
#
#                                                vote_desc  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 87946  Lower Rio Grande Valley Water Resources Conser...
# 87947  Making further continuing appropriations for F...
# 87948  Making further continuing appropriations for t...
# 87949  Making further continuing appropriations for f...
# 87950  Making Appropriations for Labor, Health and Hu...
#
#                                            vote_question  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 87946  On Motion to Suspend the Rules and Pass, As Am...
# 87947                                         On Passage
# 87948                                         On Passage
# 87949                                         On Passage
# 87950               On Agreeing to the Conference Report
#
#                                                 dtl_desc
# 0      TO AMEND H.R. 2, (1 STAT. 24, APP. 7-4-1789), ...
# 1      TO PASS THE RESOLUTION THAT IT APPEARS TO THIS...
# 2      TO AMEND H.R. 8, (1 STAT. 28, APP. 7-27-1789),...
# 3      TO AMEND H.R. 8, SO AS TO ELIMINATE THE PRESID...
# 4                                        TO PASS H.R. 8.
# ...                                                  ...
# 87946  S 1761 QUESTION: ON MOTION TO SUSPEND THE RULE...
# 87947  H J RES 126 QUESTION: ON PASSAGE MAKING FURTHE...
# 87948  H J RES 127 QUESTION: ON PASSAGE MAKING FURTHE...
# 87949  H J RES 128 QUESTION: ON PASSAGE MAKING FURTHE...
# 87950  H R 4577 QUESTION: ON AGREEING TO THE CONFEREN...
#
# [87943 rows x 18 columns]

# %%
# Funktion zur Bereinigung und Tokenisierung des Textes
def preprocess_text(text):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    # Zerlege den Text in Wörter (Tokenisierung)
    words = text.split()
    return words

# Wende die Funktion auf die Spalte dtl_desc an und erhalte eine Liste aller Wörter
all_words = []
df['dtl_desc'].apply(lambda x: all_words.extend(preprocess_text(x)))

# Zähle die Häufigkeit jedes Wortes
word_counts = Counter(all_words)

# Ausgabe der häufigsten Wörter
common_words = word_counts.most_common(50)  # Hier werden die 50 häufigsten Wörter angezeigt
for word, count in common_words:
    print(f'{word}: {count}')
# Out:
# the: 213443
# to: 192024
# of: 138511
# and: 67241
# for: 53941
# a: 47021
# in: 36449
# hr: 34967
# by: 34511
# on: 30033
# amend: 26353
# p: 25995
# amendment: 25545
# that: 23624
# bill: 22444
# s: 20036
# act: 17026
# be: 15833
# h: 14241
# motion: 13970
# house: 13406
# from: 13283
# pass: 12944
# or: 12078
# resolution: 11966
# as: 11443
# which: 10932
# an: 10638
# providing: 10375
# with: 10137
# committee: 10042
# senate: 9909
# r: 9380
# appropriations: 8994
# res: 8293
# table: 8181
# states: 7865
# fiscal: 7073
# shall: 6818
# order: 6715
# any: 6557
# report: 6356
# not: 6314
# passed: 6290
# at: 6255
# consideration: 6173
# no: 5726
# us: 5577
# stat: 5538
# rules: 5516

# %%
from nltk.corpus import stopwords
import nltk

# Stelle sicher, dass du die Stoppwörter herunterlädst, falls noch nicht geschehen
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/robinfischer/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Funktion zur Bereinigung und Tokenisierung des Textes
def preprocess_text(text):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    # Zerlege den Text in Wörter (Tokenisierung)
    words = text.split()
    return words

# Definiere die Stoppwörter
stop_words = set(stopwords.words('english'))

# Wende die Funktion auf die Spalte dtl_desc an und erhalte eine Liste aller Wörter, exklusive der Stoppwörter
all_words = []
df['dtl_desc'].apply(lambda x: all_words.extend([word for word in preprocess_text(x) if word not in stop_words]))

# Zähle die Häufigkeit jedes Wortes
word_counts = Counter(all_words)

# Ausgabe der häufigsten Wörter
common_words = word_counts.most_common(10000)  # Hier werden die 50 häufigsten Wörter angezeigt
for word, count in common_words:
    print(f'{word}: {count}')

# Speichere die Wortfrequenzen in einem DataFrame
word_freq_df = pd.DataFrame(common_words, columns=['word', 'count'])

# Speichere die Ergebnisse in einer Excel-Datei
word_freq_df.to_excel('word_frequencies.xlsx', index=False)

print("Die häufigsten Wörter wurden in 'word_frequencies.xlsx' gespeichert.")
# Out:
# hr: 34967
# amend: 26353
# p: 25995
# amendment: 25545
# bill: 22444
# act: 17026
# h: 14241
# motion: 13970
# house: 13406
# pass: 12944
# resolution: 11966
# providing: 10375
# committee: 10042
# senate: 9909
# inflation: 68
# trillion: 68
# specify: 67
# prayer: 67
# seventh: 67
# inconsistent: 67
# acceptance: 67
# candidate: 67
# certified: 67
# regardless: 67
# vacant: 67
# exclusion: 67
# dock: 67
# apart: 67
# objections: 67
# franchise: 67
# senior: 67
# nevada: 67
# mental: 67
# gains: 67
# airports: 67
# incentives: 67
# weicker: 67
# rpa: 67
# bringing: 66
# opening: 66
# purchasing: 66
# secured: 66
# levy: 66
# whereby: 66
# misdemeanor: 66
# jefferson: 66
# honor: 66
# forms: 66
# postponing: 66
# haiti: 66
# principles: 66
# canals: 66
# fill: 66
# stations: 66
# taxing: 66
# responsible: 66
# turkey: 66
# includes: 66
# needed: 66
# coastal: 66
# nationals: 66
# glenn: 66
# rebels: 66
# livestock: 66
# occupational: 66
# commissioned: 65
# passengers: 65
# exceptions: 65
# continuance: 65
# albert: 65
# deems: 65
# hostilities: 65
# raises: 65
# credentials: 65
# lumber: 65
# putting: 65
# effects: 65
# exported: 65
# ga: 65
# influence: 65
# society: 65
# simon: 65
# subscription: 65
# enemy: 65
# equivalent: 65
# chiefs: 65
# dispose: 65
# ala: 65
# cap: 65
# certify: 65
# evening: 65
# governmental: 65
# data: 65
# subsequently: 65
# archer: 65
# unions: 65
# achieve: 65
# taxpayers: 65
# disapprove: 65
# textile: 65
# abourezk: 65
# competitiveness: 65
# supplying: 64
# doors: 64
# pro: 64
# recognized: 64
# fifteen: 64
# option: 64
# intent: 64
# integrity: 64
# taxed: 64
# stevens: 64
# consul: 64
# permission: 64
# function: 64
# seizure: 64
# double: 64
# exclusively: 64
# hampshire: 64
# indirectly: 64
# stated: 64
# repairing: 64
# cuban: 64
# findings: 64
# falls: 64
# asia: 64
# apparent: 64
# fuels: 64
# lobbying: 64
# flexibility: 64
# cambodia: 64
# reauthorize: 64
# rhode: 63
# met: 63
# origin: 63
# twelve: 63
# attempt: 63
# recommend: 63
# died: 63
# remarks: 63
# connecticut: 63
# unemployed: 63
# martial: 63
# revolution: 63
# stores: 63
# classes: 63
# louisville: 63
# guaranteed: 63
# oh: 63
# domain: 63
# disapproval: 63
# exemptions: 63
# mines: 63
# feet: 63
# irrigation: 63
# lunch: 63
# counties: 62
# unfinished: 62
# tract: 62
# orphans: 62
# indemnity: 62
# london: 62
# equally: 62
# drawback: 62
# restored: 62
# refund: 62
# chickasaw: 62
# dixon: 62
# morgan: 62
# marshal: 62
# davis: 62
# copper: 62
# adjourned: 62
# corrections: 62
# armor: 62
# manpower: 62
# evaluation: 62
# scenic: 62
# epa: 62
# amtrak: 62
# subscribers: 61
# inexpedient: 61
# withholding: 61
# divided: 61
# wm: 61
# consumption: 61
# build: 61
# treason: 61
# defendant: 61
# requests: 61
# described: 61
# eliminated: 61
# clothing: 61
# fully: 61
# types: 61
# transactions: 61
# problems: 61
# applications: 61
# gasoline: 61
# goals: 61
# nickles: 61
# memorials: 60
# compensate: 60
# transferred: 60
# concerns: 60
# frauds: 60
# organize: 60
# methods: 60
# execute: 60
# hamilton: 60
# stockholders: 60
# secy: 60
# computer: 43
# wellstone: 43
# processes: 42
# consist: 42
# defeated: 42
# demands: 42
# cession: 42
# equality: 42
# speedy: 42
# dangerous: 42
# harrison: 42
# defend: 42
# deliver: 42
# sovereignty: 42
# christopher: 42
# submarine: 42
# defined: 42
# rev: 42
# transported: 42
# suffering: 42
# seminole: 42
# filled: 42
# bands: 42
# sole: 42
# columbus: 42
# negro: 42
# abandoned: 42
# madison: 42
# detailed: 42
# boats: 42
# via: 42
# avenue: 42
# poll: 42
# exchanges: 42
# subcommittee: 42
# dues: 42
# relieving: 42
# tariffs: 42
# id: 42
# enrollment: 42
# homesteads: 42
# tenure: 42
# criteria: 42
# uranium: 42
# packwood: 42
# clarifies: 42
# pressler: 42
# hefley: 42
# assistants: 41
# residue: 41
# cruisers: 41
# amity: 41
# content: 41
# executed: 41
# choose: 41
# seeks: 41
# validity: 41
# monroe: 41
# acted: 41
# consisting: 41
# cavalry: 41
# seized: 41
# occupancy: 41
# maps: 41
# flour: 41
# yd: 41
# messengers: 41
# prompt: 41
# conformity: 41
# voluntarily: 41
# unsold: 41
# earlier: 41
# historical: 41
# retroactive: 41
# press: 41
# married: 41
# exploration: 41
# assume: 41
# honduras: 41
# minerals: 41
# goat: 41
# jute: 41
# mandates: 41
# identification: 41
# spence: 41
# worlds: 41
# displaced: 41
# options: 41
# automobile: 41
# resource: 41
# standby: 41
# davisbacon: 41
# dod: 41
# sdi: 41
# bingaman: 41
# catastrophic: 41
# rva: 41
# herzegovina: 41
# even: 40
# jurors: 40
# forty: 40
# reads: 40
# incorporation: 40
# settled: 40
# lately: 40
# attempts: 40
# entirely: 40
# deportation: 40
# reporters: 40
# assign: 40
# originally: 40
# registry: 40
# hear: 40
# chesapeake: 40
# regards: 40
# effectiveness: 40
# deals: 40
# foregoing: 40
# denominations: 40
# yarn: 40
# statue: 40
# bagging: 40
# volume: 40
# needy: 40
# accompany: 40
# fail: 40
# allotment: 40
# awarding: 40
# caps: 40
# curtis: 40
# card: 40
# enact: 40
# substantially: 40
# shipment: 40
# hemisphere: 40
# threatened: 40
# withhold: 40
# ineligible: 40
# recruitment: 40
# griffin: 40
# appalachian: 40
# nonmilitary: 40
# bargaining: 40
# currently: 40
# ferguson: 40
# laos: 40
# whitten: 40
# wetlands: 40
# offshore: 40
# entitlement: 40
# lying: 39
# holland: 39
# going: 39
# enumerated: 39
# clair: 39
# negotiated: 39
# statehood: 39
# friendly: 39
# propriety: 39
# assessed: 39
# yrs: 39
# accountability: 39
# recommending: 39
# concurrence: 39
# introduced: 39
# np: 39
# licensed: 39
# violate: 39
# thompson: 39
# degree: 39
# italy: 39
# conform: 39
# unexpended: 39
# discriminate: 39
# quarters: 39
# break: 39
# mechanics: 39
# asked: 39
# refuge: 39
# fraudulent: 39
# houston: 39
# check: 39
# fla: 39
# charitable: 39
# forced: 39
# hides: 39
# clayton: 39
# calender: 39
# farms: 39
# wa: 39
# adult: 39
# facilitation: 39
# geneva: 39
# involvement: 39
# mandate: 39
# range: 39
# capehart: 39
# disparate: 6
# retooling: 6
# condit: 6
# torres: 6
# eurasian: 6
# americanmade: 6
# electrichybrid: 6
# rwi: 6
# hoke: 6
# antieconomic: 6
# zimmer: 6
# nbs: 6
# prochildren: 6
# crapo: 6
# lifestyle: 6
# predators: 6
# pelosi: 6
# jazz: 6
# mckeon: 6
# ror: 6
# wetland: 6
# moseleybraun: 6
# gene: 6
# orton: 6
# visclosky: 6
# brownback: 6
# greenwood: 6
# bunning: 6
# canola: 6
# kiwifruit: 6
# reinvention: 6
# teresa: 6
# susquehanna: 5
# rds: 5
# happiness: 5
# algerine: 5
# nova: 5
# scotia: 5
# sequestration: 5
# forsyth: 5
# implied: 5
# satisfying: 5
# unanimously: 5
# admissable: 5
# constituents: 5
# convoys: 5
# darden: 5
# eventual: 5
# fairly: 5
# esq: 5
# summoning: 5
# scandalous: 5
# augmentation: 5
# packets: 5
# blacks: 5
# mcknight: 5
# disrespect: 5
# mausoleum: 5
# malicious: 5
# await: 5
# entrusted: 5
# asserting: 5
# blame: 5
# danish: 5
# desirous: 5
# lynn: 5
# chickasaws: 5
# encroachments: 5
# attested: 5
# infraction: 5
# companys: 5
# abused: 5
# oppressive: 5
# callender: 5
# informer: 5
# hoge: 5
# misrepresentation: 5
# delawares: 5
# devolve: 5
# insanity: 5
# pronounce: 5
# extinguishment: 5
# showed: 5
# mead: 5
# repugnant: 5
# leander: 5
# recommitt: 5
# jenkins: 5
# acknowledged: 5
# inaugurated: 5
# openly: 5
# govenment: 5
# believed: 5
# elias: 5
# informal: 5
# practiced: 5
# commerical: 5
# leagues: 5
# knight: 5
# Die häufigsten Wörter wurden in 'word_frequencies.xlsx' gespeichert.

# %%
from nltk.corpus import stopwords
from nltk.util import ngrams
import nltk


# Erstelle Bigramme
bigrams = list(ngrams(all_words, 2))

# Zähle die Häufigkeit der Bigramme
bigram_counts = Counter(bigrams)

# Ausgabe der häufigsten Bigramme
common_bigrams = bigram_counts.most_common(50)  # Hier werden die 50 häufigsten Bigramme angezeigt
for bigram, count in common_bigrams:
    print(f'{bigram}: {count}')
# Out:
# ('amend', 'hr'): 8958
# ('h', 'r'): 8827
# ('p', 'amend'): 7133
# ('pass', 'hr'): 5420
# ('united', 'states'): 5157
# ('hr', 'bill'): 5054
# ('suspend', 'rules'): 4315
# ('motion', 'passed'): 4090
# ('amendment', 'hr'): 3729
# ('fiscal', 'year'): 3517
# ('p', 'pass'): 3056
# ('conference', 'report'): 2936
# ('h', 'res'): 2910
# ('amend', 'h'): 2819
# ('making', 'appropriations'): 2634
# ('rules', 'pass'): 2459
# ('p', 'table'): 2449
# ('committee', 'whole'): 2142
# ('motion', 'made'): 1894
# ('bill', 'making'): 1882
# ('p', 'adjourn'): 1873
# ('motion', 'failed'): 1843
# ('senate', 'amendment'): 1837
# ('j', 'res'): 1786
# ('resolution', 'providing'): 1759
# ('hr', 'stat'): 1707
# ('pass', 'h'): 1705
# ('reconsider', 'vote'): 1698
# ('report', 'hr'): 1670
# ('consideration', 'hr'): 1668
# ('amendment', 'h'): 1637
# ('year', 'ending'): 1624
# ('stat', 'bill'): 1617
# ('district', 'columbia'): 1608
# ('house', 'agreed'): 1569
# ('see', 'notes'): 1515
# ('bill', 'providing'): 1473
# ('house', 'rejected'): 1462
# ('made', 'debate'): 1410
# ('r', 'stat'): 1323
# ('hr', 'providing'): 1317
# ('h', 'j'): 1294
# ('amendment', 'provides'): 1282
# ('third', 'reading'): 1274
# ('previous', 'question'): 1258
# ('pass', 'resolution'): 1208
# ('bill', 'hr'): 1190
# ('amend', 'amendment'): 1188
# ('adjourn', 'motion'): 1177
# ('nature', 'substitute'): 1167

# %%
# Entferne Zeilen mit fehlenden Werten in dtl_desc, yea_count oder nay_count
df = df.dropna(subset=['dtl_desc', 'yea_count', 'nay_count'])

# Funktion zur Bereinigung und Überprüfung, ob beide Begriffe im Text vorkommen
def contains_terms(text, terms):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    return all(term in text for term in terms)

# Definiere die zu suchenden Begriffe
search_terms = ['nature', 'substitute']

# Filtere die Zeilen, die beide Begriffe enthalten
filtered_df = df[df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms))]

# Berechne die Summe von yea_count und nay_count für diese gefilterten Zeilen
total_yea_count = filtered_df['yea_count'].sum()
total_nay_count = filtered_df['nay_count'].sum()

# Ausgabe der Ergebnisse
print(f'Total yea_count für "nature substitute": {total_yea_count}')
print(f'Total nay_count für "nature substitute": {total_nay_count}')

# Berechne den Durchschnitt von yea_count und nay_count für diese gefilterten Zeilen
average_yea_count = filtered_df['yea_count'].mean()
average_nay_count = filtered_df['nay_count'].mean()

print(f'Durchschnittlicher yea_count für "nature substitute": {average_yea_count}')
print(f'Durchschnittlicher nay_count für "nature substitute": {average_nay_count}')
# Out:
# Total yea_count für "nature substitute": 121936
# Total nay_count für "nature substitute": 149303
# Durchschnittlicher yea_count für "nature substitute": 104.57632933104631
# Durchschnittlicher nay_count für "nature substitute": 128.04716981132074

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# Entferne Zeilen mit fehlenden Werten in dtl_desc, yea_count oder nay_count
df = df.dropna(subset=['dtl_desc', 'yea_count', 'nay_count'])

# Konvertiere die Spalte 'date' in ein Datetime-Format ohne explizites Format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Konvertiere die Spalten 'yea_count' und 'nay_count' in numerische Werte und entferne nicht konvertierbare Werte
df['yea_count'] = pd.to_numeric(df['yea_count'], errors='coerce')
df['nay_count'] = pd.to_numeric(df['nay_count'], errors='coerce')

# Entferne Zeilen, bei denen die Konvertierung fehlschlug (d.h. wo NaN-Werte entstanden sind)
df = df.dropna(subset=['yea_count', 'nay_count'])

# Sicherstellen, dass 'yea_count' und 'nay_count' nur numerische Werte enthalten
df = df[df['yea_count'].apply(lambda x: isinstance(x, (int, float)))]
df = df[df['nay_count'].apply(lambda x: isinstance(x, (int, float)))]

# Funktion zur Bereinigung und Überprüfung, ob beide Begriffe im Text vorkommen
def contains_terms(text, terms):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    return all(term in text for term in terms)

# Definiere die zu suchenden Begriffe
search_terms = ['nature', 'substitute']

# Filtere die Zeilen, die beide Begriffe enthalten
filtered_df = df[df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms))]

# Gruppiere nach Datum und summiere yea_count und nay_count
filtered_df = filtered_df.set_index('date')
time_series_df = filtered_df[['yea_count', 'nay_count']].resample('M').sum()

# Apply rolling mean to smooth the data
time_series_df['yea_count'] = time_series_df['yea_count'].rolling(window=12).mean()
time_series_df['nay_count'] = time_series_df['nay_count'].rolling(window=12).mean()

# Plotten der Zeitreihe
plt.figure(figsize=(14, 7))
plt.plot(time_series_df.index, time_series_df['yea_count'], label='Yea Count (smoothed)', color='green')
plt.plot(time_series_df.index, time_series_df['nay_count'], label='Nay Count (smoothed)', color='red')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Yea and Nay Counts for "Nature Substitute" Over Time (Smoothed)')
plt.legend()
plt.grid(True)
plt.ylim(0, max(time_series_df['yea_count'].max(), time_series_df['nay_count'].max()) * 1.1)
plt.show()

# Berechne die Summe von yea_count und nay_count für diese gefilterten Zeilen
total_yea_count = filtered_df['yea_count'].sum()
total_nay_count = filtered_df['nay_count'].sum()

# Ausgabe der Ergebnisse
print(f'Total yea_count für "nature substitute": {total_yea_count}')
print(f'Total nay_count für "nature substitute": {total_nay_count}')

# Berechne den Durchschnitt von yea_count und nay_count für diese gefilterten Zeilen
average_yea_count = filtered_df['yea_count'].mean()
average_nay_count = filtered_df['nay_count'].mean()

print(f'Durchschnittlicher yea_count für "nature substitute": {average_yea_count}')
print(f'Durchschnittlicher nay_count für "nature substitute": {average_nay_count}')
# Out:
# Total yea_count für "nature substitute": 121936
# Total nay_count für "nature substitute": 149303
# Durchschnittlicher yea_count für "nature substitute": 104.57632933104631
# Durchschnittlicher nay_count für "nature substitute": 128.04716981132074

# %%
# Stacked Area Plot
plt.figure(figsize=(14, 7))
plt.stackplot(time_series_df.index, time_series_df['yea_count'], time_series_df['nay_count'], labels=['Yea Count', 'Nay Count'], colors=['green', 'red'])
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Stacked Area Plot of Yea and Nay Counts for "Nature Substitute" Over Time')
plt.legend(loc='upper left')
plt.show()

# %%
from nltk.corpus import stopwords
from nltk.util import ngrams
import nltk


# Erstelle Bigramme
bigrams = list(ngrams(all_words, 2))

# Zähle die Häufigkeit der Bigramme
bigram_counts = Counter(bigrams)

# Ausgabe der häufigsten Bigramme
common_bigrams = bigram_counts.most_common(100)  # Hier werden die 50 häufigsten Bigramme angezeigt
for bigram, count in common_bigrams:
    print(f'{bigram}: {count}')
# Out:
# ('amend', 'hr'): 8958
# ('h', 'r'): 8827
# ('p', 'amend'): 7133
# ('pass', 'hr'): 5420
# ('united', 'states'): 5157
# ('hr', 'bill'): 5054
# ('suspend', 'rules'): 4315
# ('motion', 'passed'): 4090
# ('amendment', 'hr'): 3729
# ('fiscal', 'year'): 3517
# ('p', 'pass'): 3056
# ('conference', 'report'): 2936
# ('h', 'res'): 2910
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    return all(term in text for term in terms)

# Definiere die zu suchenden Begriffe
search_terms = ['agriculture', 'bill']

# Filtere die Zeilen, die beide Begriffe enthalten
filtered_df = df[df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms))]

# Berechne die Summe von yea_count und nay_count für diese gefilterten Zeilen
total_yea_count = filtered_df['yea_count'].sum()
total_nay_count = filtered_df['nay_count'].sum()

# Ausgabe der Ergebnisse
print(f'Total yea_count für "aggriculture bill": {total_yea_count}')
print(f'Total nay_count für "aggriculture bill": {total_nay_count}')

# Berechne den Durchschnitt von yea_count und nay_count für diese gefilterten Zeilen
average_yea_count = filtered_df['yea_count'].mean()
average_nay_count = filtered_df['nay_count'].mean()

print(f'Durchschnittlicher yea_count für "agriculture-bill": {average_yea_count}')
print(f'Durchschnittlicher nay_count für "aggriculture-bill": {average_nay_count}')
# Out:
# Total yea_count für "aggriculture bill": 43100
# Total nay_count für "aggriculture bill": 25253
# Durchschnittlicher yea_count für "agriculture-bill": 134.6875
# Durchschnittlicher nay_count für "aggriculture-bill": 78.915625

# %%
import pandas as pd
import re

# Entferne Zeilen mit fehlenden Werten in dtl_desc, yea_count oder nay_count
df = df.dropna(subset=['dtl_desc', 'yea_count', 'nay_count'])

# Funktion zur Bereinigung und Überprüfung, ob beide Begriffe im Text vorkommen
def contains_terms(text, terms):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    return all(term in text for term in terms)

# Definiere die zu suchenden Begriffe für die Abstimmung
search_terms_nature_substitute = ['agriculture', 'bill']

# Filtere die Zeilen, die beide Begriffe enthalten
filtered_df_nature_substitute = df[df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms_nature_substitute))]

# Berechne die Summe von yea_count und nay_count für diese gefilterten Zeilen
total_yea_count_ns = filtered_df_nature_substitute['yea_count'].sum()
total_nay_count_ns = filtered_df_nature_substitute['nay_count'].sum()

# Ausgabe der Ergebnisse
print(f'Total yea_count für "agriculture bill": {total_yea_count_ns}')
print(f'Total nay_count für "agriculture bill": {total_nay_count_ns}')

# Berechne den Durchschnitt von yea_count und nay_count für diese gefilterten Zeilen
average_yea_count_ns = filtered_df_nature_substitute['yea_count'].mean()
average_nay_count_ns = filtered_df_nature_substitute['nay_count'].mean()

print(f'Durchschnittlicher yea_count für "agriculture bill": {average_yea_count_ns}')
print(f'Durchschnittlicher nay_count für "agriculture bill": {average_nay_count_ns}')

# Definiere die zu suchenden Begriffe für die Kombination "agriculture bill"
search_terms_agriculture_bill = ['agriculture', 'bill']

# Zähle die Zeilen, die beide Begriffe enthalten
agriculture_bill_count = df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms_agriculture_bill)).sum()

print(f'Anzahl der Vorkommen der Kombination "agriculture bill": {agriculture_bill_count}')
# Out:
# Total yea_count für "agriculture bill": 43100
# Total nay_count für "agriculture bill": 25253
# Durchschnittlicher yea_count für "agriculture bill": 134.6875
# Durchschnittlicher nay_count für "agriculture bill": 78.915625
# Anzahl der Vorkommen der Kombination "agriculture bill": 320

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# Entferne Zeilen mit fehlenden Werten in dtl_desc, yea_count oder nay_count
df = df.dropna(subset=['dtl_desc', 'yea_count', 'nay_count'])

# Konvertiere die Spalte 'date' in ein Datetime-Format ohne explizites Format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Konvertiere die Spalten 'yea_count' und 'nay_count' in numerische Werte und entferne nicht konvertierbare Werte
df['yea_count'] = pd.to_numeric(df['yea_count'], errors='coerce')
df['nay_count'] = pd.to_numeric(df['nay_count'], errors='coerce')

# Entferne Zeilen, bei denen die Konvertierung fehlschlug (d.h. wo NaN-Werte entstanden sind)
df = df.dropna(subset=['yea_count', 'nay_count'])

# Sicherstellen, dass 'yea_count' und 'nay_count' nur numerische Werte enthalten
df = df[df['yea_count'].apply(lambda x: isinstance(x, (int, float)))]
df = df[df['nay_count'].apply(lambda x: isinstance(x, (int, float)))]

# Funktion zur Bereinigung und Überprüfung, ob beide Begriffe im Text vorkommen
def contains_terms(text, terms):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    return all(term in text for term in terms)

# Definiere die zu suchenden Begriffe
search_terms = ['agriculture', 'bill']

# Filtere die Zeilen, die beide Begriffe enthalten
filtered_df = df[df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms))]

# Gruppiere nach Datum und summiere yea_count und nay_count
filtered_df = filtered_df.set_index('date')
time_series_df = filtered_df[['yea_count', 'nay_count']].resample('M').sum()

# Apply rolling mean to smooth the data
time_series_df['yea_count'] = time_series_df['yea_count'].rolling(window=12).mean()
time_series_df['nay_count'] = time_series_df['nay_count'].rolling(window=12).mean()

# Plotten der Zeitreihe
plt.figure(figsize=(14, 7))
plt.plot(time_series_df.index, time_series_df['yea_count'], label='Yea Count (smoothed)', color='green')
plt.plot(time_series_df.index, time_series_df['nay_count'], label='Nay Count (smoothed)', color='red')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Yea and Nay Counts for "Agriculture Bill" Over Time (Smoothed)')
plt.legend()
plt.grid(True)
plt.ylim(0, max(time_series_df['yea_count'].max(), time_series_df['nay_count'].max()) * 1.1)
plt.show()

# Berechne die Summe von yea_count und nay_count für diese gefilterten Zeilen
total_yea_count = filtered_df['yea_count'].sum()
total_nay_count = filtered_df['nay_count'].sum()

# Ausgabe der Ergebnisse
print(f'Total yea_count für "agriculture bill": {total_yea_count}')
print(f'Total nay_count für "agriculture bill": {total_nay_count}')

# Berechne den Durchschnitt von yea_count und nay_count für diese gefilterten Zeilen
average_yea_count = filtered_df['yea_count'].mean()
average_nay_count = filtered_df['nay_count'].mean()

print(f'Durchschnittlicher yea_count für "Agriculture Bill": {average_yea_count}')
print(f'Durchschnittlicher nay_count für "agriculture bill": {average_nay_count}')
# Out:
# Total yea_count für "agriculture bill": 43100
# Total nay_count für "agriculture bill": 25253
# Durchschnittlicher yea_count für "Agriculture Bill": 134.6875
# Durchschnittlicher nay_count für "agriculture bill": 78.915625

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# Entferne Zeilen mit fehlenden Werten in dtl_desc, yea_count oder nay_count
df = df.dropna(subset=['dtl_desc', 'yea_count', 'nay_count'])

# Konvertiere die Spalte 'date' in ein Datetime-Format ohne explizites Format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Konvertiere die Spalten 'yea_count' und 'nay_count' in numerische Werte und entferne nicht konvertierbare Werte
df['yea_count'] = pd.to_numeric(df['yea_count'], errors='coerce')
df['nay_count'] = pd.to_numeric(df['nay_count'], errors='coerce')

# Entferne Zeilen, bei denen die Konvertierung fehlschlug (d.h. wo NaN-Werte entstanden sind)
df = df.dropna(subset=['yea_count', 'nay_count'])

# Sicherstellen, dass 'yea_count' und 'nay_count' nur numerische Werte enthalten
df = df[df['yea_count'].apply(lambda x: isinstance(x, (int, float)))]
df = df[df['nay_count'].apply(lambda x: isinstance(x, (int, float)))]

# Funktion zur Bereinigung und Überprüfung, ob beide Begriffe im Text vorkommen
def contains_terms(text, terms):
    # Entferne Sonderzeichen und Zahlen
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # In Kleinbuchstaben umwandeln
    text = text.lower()
    return all(term in text for term in terms)

# Definiere die zu suchenden Begriffe
search_terms = ['agriculture', 'bill']

# Filtere die Zeilen, die beide Begriffe enthalten
filtered_df = df[df['dtl_desc'].apply(lambda x: contains_terms(x, search_terms))]

# Begrenze den Datensatz auf die Periode bis 1900
filtered_df = filtered_df[filtered_df['date'] <= '1900-12-31']

# Gruppiere nach Datum und summiere yea_count und nay_count
filtered_df = filtered_df.set_index('date')
time_series_df = filtered_df[['yea_count', 'nay_count']].resample('M').sum()

# Apply rolling mean to smooth the data
time_series_df['yea_count'] = time_series_df['yea_count'].rolling(window=12).mean()
time_series_df['nay_count'] = time_series_df['nay_count'].rolling(window=12).mean()

# Plotten der Zeitreihe
plt.figure(figsize=(14, 7))
plt.plot(time_series_df.index, time_series_df['yea_count'], label='Yea Count (smoothed)', color='green')
plt.plot(time_series_df.index, time_series_df['nay_count'], label='Nay Count (smoothed)', color='red')

#Highlight 1865 
plt.axvline(pd.Timestamp('1865-01-01'), color='purple', linestyle='--', lw=2, label='Year 1865')

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Yea and Nay Counts for "Agriculture Bill" Over Time (Smoothed)')
plt.legend()
plt.grid(True)
plt.ylim(0, max(time_series_df['yea_count'].max(), time_series_df['nay_count'].max()) * 1.1)
plt.show()

# Berechne die Summe von yea_count und nay_count für diese gefilterten Zeilen
total_yea_count = filtered_df['yea_count'].sum()
total_nay_count = filtered_df['nay_count'].sum()

# Ausgabe der Ergebnisse
print(f'Total yea_count für "agriculture bill": {total_yea_count}')
print(f'Total nay_count für "agriculture bill": {total_nay_count}')

# Berechne den Durchschnitt von yea_count und nay_count für diese gefilterten Zeilen
average_yea_count = filtered_df['yea_count'].mean()
average_nay_count = filtered_df['nay_count'].mean()

print(f'Durchschnittlicher yea_count für "Agriculture Bill": {average_yea_count}')
print(f'Durchschnittlicher nay_count für "agriculture bill": {average_nay_count}')
# Out:
# Total yea_count für "agriculture bill": 3700
# Total nay_count für "agriculture bill": 3354
# Durchschnittlicher yea_count für "Agriculture Bill": 66.07142857142857
# Durchschnittlicher nay_count für "agriculture bill": 59.892857142857146
